# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy as sp
import warnings
import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\POORNIMA\Downloads\CricketWorldCup2023.csv")

# %%
data
# Out:
#     Match ID  Match Date Match Time         City  \
# 0          1  05-10-2023   02:00 PM    Ahmedabad
# 1          2  06-10-2023   02:00 PM    Hyderabad
# 2          3  07-10-2023   02:00 PM  Dharamshala
# 3          4  07-10-2023   02:00 PM        Delhi
# 4          5  08-10-2023   02:00 PM      Chennai
# 5          6  09-10-2023   02:00 PM    Hyderabad
# 6          7  10-10-2023   10:30 AM  Dharamshala
# 7          8  10-10-2023   02:00 PM    Hyderabad
# 8          9  11-10-2023   02:00 PM        Delhi
# 9         10  12-10-2023   02:00 PM      Lucknow
# 10        11  13-10-2023   02:00 PM      Chennai
# 11        12  14-10-2023   02:00 PM    Ahmedabad
# 12        13  15-10-2023   02:00 PM        Delhi
# 13        14  16-10-2023   02:00 PM      Lucknow
# 14        15  17-10-2023   02:00 PM  Dharamshala
# 15        16  18-10-2023   02:00 PM      Chennai
# 16        17  19-10-2023   02:00 PM         Pune
# 17        18  20-10-2023   02:00 PM    Bangalore
# ...

# %%
data.head()
# Out:
#    Match ID  Match Date Match Time         City                    Stadium  \
# 0         1  05-10-2023   02:00 PM    Ahmedabad      Narendra Modi Stadium
# 1         2  06-10-2023   02:00 PM    Hyderabad               Eden Gardens
# 2         3  07-10-2023   02:00 PM  Dharamshala               HPCA Stadium
# 3         4  07-10-2023   02:00 PM        Delhi       Arun Jaitley Stadium
# 4         5  08-10-2023   02:00 PM      Chennai  M. A. Chidambaram Stadium
#
#          Team A       Team B  Toss Winner Toss Decision  Score A  Score B
# 0       England   NewZealand   NewZealand         Field      282      283
# 1      Pakistan  Netherlands  Netherlands         Field      286      205
# 2   Afghanistan   Bangladesh   Bangladesh         Field      156      158
# 3  South Africa    Sri Lanka    Sri Lanka         Field      428      326
# 4     Australia        India    Australia           Bat      199      201

# %%
data.describe()
# Out:
#        Match ID     Score A     Score B
# count     48.00   48.000000   48.000000
# mean      24.50  282.562500  230.750000
# std       14.00   76.709429   70.621707
# min        1.00  142.000000   55.000000
# 25%       12.75  237.250000  188.750000
# 50%       24.50  280.500000  231.000000
# 75%       36.25  347.250000  276.000000
# max       48.00  428.000000  383.000000

# %%
data.isnull().sum()
# Out:
# Match ID         0
# Match Date       0
# Match Time       0
# City             0
# Stadium          0
# Team A           0
# Team B           0
# Toss Winner      0
# Toss Decision    0
# Score A          0
# Score B          0
# dtype: int64

# %%
data.value_counts()
# Out:
# Match ID  Match Date  Match Time  City         Stadium                                  Team A        Team B        Toss Winner   Toss Decision  Score A  Score B
# 1         05-10-2023  02:00 PM    Ahmedabad    Narendra Modi Stadium                    England       NewZealand    NewZealand    Field          282      283        1
# 2         06-10-2023  02:00 PM    Hyderabad    Eden Gardens                             Pakistan      Netherlands   Netherlands   Field          286      205        1
# 27        28-10-2023  10:30 AM    Dharamshala  HPCA Stadium                             Australia     NewZealand    NewZealand    Field          388      383        1
# 28        28-10-2023  02:00 PM    Kolkata      Eden Gardens                             Netherlands   Bangladesh    Netherlands   Bat            142      229        1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Match ID       48 non-null     int64
#  1   Match Date     48 non-null     object
#  2   Match Time     48 non-null     object
#  3   City           48 non-null     object
#  4   Stadium        48 non-null     object
#  5   Team A         48 non-null     object
#  6   Team B         48 non-null     object
#  7   Toss Winner    48 non-null     object
#  8   Toss Decision  48 non-null     object
#  9   Score A        48 non-null     int64
#  10  Score B        48 non-null     int64
# dtypes: int64(3), object(8)
# memory usage: 4.3+ KB

# %%
data.dtypes
# Out:
# Match ID          int64
# Match Date       object
# Match Time       object
# City             object
# Stadium          object
# Team A           object
# Team B           object
# Toss Winner      object
# Toss Decision    object
# Score A           int64
# Score B           int64
# dtype: object

# %%
print('Dataset contains {} rows & {} columns'.format(data.shape[0],data.shape[1]))
# Out:
# Dataset contains 48 rows & 11 columns

# %%
data.columns
# Out:
# Index(['Match ID', 'Match Date', 'Match Time', 'City', 'Stadium', 'Team A',
#        'Team B', 'Toss Winner', 'Toss Decision', 'Score A', 'Score B'],
#       dtype='object')

# %%
data.isnull().any()
# Out:
# Match ID         False
# Match Date       False
# Match Time       False
# City             False
# Stadium          False
# Team A           False
# Team B           False
# Toss Winner      False
# Toss Decision    False
# Score A          False
# Score B          False
# dtype: bool

# %%
data.hist()
plt.show()

# %%
sns.pairplot(data=data)

# %%
sns.lineplot(x='Score A', y= 'Score B', data=data)
# Out:
# <Axes: xlabel='Score A', ylabel='Score B'>

# %%
plt.style.use("default")

sns.kdeplot(x='Score A', y= 'Score B', data=data)
# Out:
# <Axes: xlabel='Score A', ylabel='Score B'>

# %%
sns.lmplot(x='Score A', y= 'Score B', data=data)

# %%
sns.jointplot(x='Score A', y= 'Score B', data=data)
